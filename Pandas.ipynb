# %%
import pandas as pd

# %% [markdown]
# Tabular(structure) data ko hanldle krny k liye panda bnaya gaya h,excel wla sara kaam,series or dataframe ye 2 datatype hain bs

# %%
a=[1,2,3]
a1=pd.Series(a)# indexes k sath values dikharha h ,individual 
display(a1)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
a2=pd.Series(a,index=["a","b","c"])
display(a2)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data={"day1":"monday","day2":"Friday","day3":"Sunday"}
a=pd.Series(data)
display(a)
# Out:
# day1    monday
# day2    Friday
# day3    Sunday
# dtype: object
